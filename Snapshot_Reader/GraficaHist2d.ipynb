# %%
# %pylab inline
from matplotlib.colors import LogNorm
# %ls
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Particle_viewer-Copy0.ipynb  Particle_viewer.ipynb  phase_Space.dat  RandomReader.c  reader.c  sample100Mpc128.png  snap100Mpc128_z0  users-guide.pdf

# %% [markdown]
# # Grafica de snap100Mpc128_z0

# %% [markdown]
# #### Optencion de los datos (solo posiciones)

# %%
array = loadtxt("phase_Space.dat")

# %%
array = array.T[2:5].T
print shape(array), len(array.T[0])
# Out:
# (698422, 3) 698422

# %%
hist2d(array.T[2], array.T[1], bins=100, norm=LogNorm(),)
colorbar()
show()
