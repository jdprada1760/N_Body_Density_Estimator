# %%
# %pylab inline
# %ls
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ics.data  Playing.ipynb  redShift0.data  redShift50.data  Tetrahedron.ipynb

# %%
initial = loadtxt("ics.data")

# %%
Ids = initial.T[0]
initial = initial.T[2:5].T
print shape(initial), len(initial.T[0])
# Out:
# (2097152, 3) 2097152

# %%
from matplotlib.colors import LogNorm
hist2d(initial.T[2], initial.T[1], bins=100, norm=LogNorm(),)
colorbar()
show()

# %%
# Out:
# [ 2.]

# %%
partial =
